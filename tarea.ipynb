# %%
import pandas as pd
data1 = pd.read_csv("Data\data1_mercadotecnia.csv") #dataframe desde un csv

# %%
data2 = pd.read_json("Data\data2_financiera.json") #dataframe desde un .json

# %%
resultado = data1.merge(data2,how='outer')
resultado
# Out:
#                                   NOMBRE  SEMESTRE1  SEMESTRE2
# 0         CINDY CAROLINA OSORTO CASTILLO       91.0       84.0
# 1        EMELI YOLIBETH FIGUEROA BONILLA       85.0       94.0
# 2         FANNY ESTEFANY CHAVEZ GONZALES        NaN        NaN
# 3            GISSELL ANAHY FLORES TORRES       90.0       84.0
# 4             IRMA ALICIA ESCOTO MONCADA       93.0       92.0
# 5          JAQUELIN YAMILETH GOMEZ CALIX       77.0       84.0
# 6     JOHANA PATRICIA ALMENDARES ORDOÑEZ       95.0       90.0
# 7          KATERIN YORLENIS BLANCO LAGOS       92.0       90.0
# 8          KATHIA KARINA LOZANO BARAHONA       85.0       72.0
# 9          KEIDY PAMELA CARRANZA ESPINAL       91.0       84.0
# 10            LESLY DANIELA AVILA AMADOR       72.0       75.0
# 11           MARIELA SARAI LOPEZ HERRERA       83.0       90.0
# 12      NAIDELYN YIRETH SANCHEZ OSEGUERA       77.0       79.0
# 13       SUREILY ELISABETH AMADOR DAVILA       77.0       70.0
# ...

# %%
 ##Promedio de notas de 1 semestre
resultado.SEMESTRE1.mean()
# Out:
# 79.05882352941177

# %%
 ##Promedio de notas de 2 semestre
resultado.SEMESTRE2.mean()
# Out:
# 85.92

# %%
##promedio de notas de todos los alumnos
prom = (resultado.SEMESTRE1.mean() + resultado.SEMESTRE2.mean())/2
prom
# Out:
# 82.48941176470589
